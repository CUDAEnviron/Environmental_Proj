# %% [markdown]
# ## Preparation of Data for Javascript Dashboard

# %%
# Import Libraries
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2

# %%
# Creating connection to the database
connection_string = f'postgres://hrcykodaiuwpab:92ba424e0b5a8c22538d55bc45ae0b239a9e1c23b25ec20d539d9e67afefa8be@ec2-3-211-167-220.compute-1.amazonaws.com:5432/d89a2icfqufifv'

conn = create_engine(connection_string)

# %%
# Create dataframe from Postgres table
dashboard_data_df = pd.read_sql("select * from dashboard_data", conn);
dashboard_data_df
# Out:
#          Country     CO2  Average_Temperature  Population           GDP  \
# 0    Afghanistan    9.02                56.96  34414000.0  6.278339e+10
# 1        Albania    4.61                54.83   2891000.0  3.322414e+10
# 2        Algeria  150.70                74.58  39728000.0  5.130000e+11
# 3         Angola   33.98                72.07  27884000.0  1.480000e+11
# 4      Argentina  199.86                58.93  43075000.0  8.400000e+11
# ..           ...     ...                  ...         ...           ...
# 141    Venezuela  170.90                79.59  30082000.0  4.830000e+11
# 142      Vietnam  180.31                77.25  92677000.0  5.410000e+11
# 143        Yemen   12.70                76.17  26498000.0  6.952109e+10
# 144       Zambia    4.30                72.84  15879000.0  5.591289e+10
# 145     Zimbabwe   12.16                72.19  13815000.0  2.503057e+10
#
#      GDP_per_Capita  CO2_per_Capita  CO2_per_Unit_GDP  Government_Rating  \
# ...

# %%
# Get Data Types
dashboard_data_df.dtypes
# Out:
# Country                 object
# CO2                    float64
# Average_Temperature    float64
# Population             float64
# GDP                    float64
# GDP_per_Capita         float64
# CO2_per_Capita         float64
# CO2_per_Unit_GDP       float64
# Government_Rating      float64
# Government_Type         object
# Paris_Agreement         object
# dtype: object

# %%
# Write out csv Data for Dashboard
dashboard_data_df.to_csv("data/dashboard_data.csv", index=False)
