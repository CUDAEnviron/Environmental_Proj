# %% [markdown]
# ## Loading Base CO2 Data to Postgress Database

# %%
# Import libraries
import pandas as pd
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2
# from config import db_password
import csv
import os

# %%
# Creating connection to the database
connection_string = f'postgres://hrcykodaiuwpab:92ba424e0b5a8c22538d55bc45ae0b239a9e1c23b25ec20d539d9e67afefa8be@ec2-3-211-167-220.compute-1.amazonaws.com:5432/d89a2icfqufifv'

engine = create_engine(connection_string)

# %%
# Load CO2 data to dataframe
co2_data_file = 'Resources/owid-co2-data.csv'
co2_data_df = pd.read_csv(co2_data_file)
co2_data_df
# Out:
#       iso_code      country  year     co2  co2_growth_prct  co2_growth_abs  \
# 0          AFG  Afghanistan  1949   0.015              NaN             NaN
# 1          AFG  Afghanistan  1950   0.084          475.000           0.070
# 2          AFG  Afghanistan  1951   0.092            8.696           0.007
# 3          AFG  Afghanistan  1952   0.092            0.000           0.000
# 4          AFG  Afghanistan  1953   0.106           16.000           0.015
# ...        ...          ...   ...     ...              ...             ...
# 24011      ZWE     Zimbabwe  2014  11.962            2.838           0.330
# 24012      ZWE     Zimbabwe  2015  12.163            1.685           0.202
# 24013      ZWE     Zimbabwe  2016  10.807          -11.146          -1.356
# 24014      ZWE     Zimbabwe  2017  12.026           11.274           1.218
# 24015      ZWE     Zimbabwe  2018  12.263            1.969           0.237
#
# ...

# %%
# Create co2_data table in Postgres DB from csv file
co2_data_df.to_sql(name="co2_data", con=engine, if_exists='replace', index=False)

# %% [markdown]
# ## Load Base Temperature Data to Postgres Database

# %%
# Load Temperature data to dataframe
temperature_data_file = 'Resources/clean_Global_temps_1901_to_2016.csv'
temperature_data_df = pd.read_csv(temperature_data_file)
temperature_data_df
# Out:
#       iso_code       country  year  Temperature
# 0          AFG   Afghanistan  1901    13.172872
# 1          AFG   Afghanistan  1902    13.342649
# 2          AFG   Afghanistan  1903    12.006417
# 3          AFG   Afghanistan  1904    12.531729
# 4          AFG   Afghanistan  1905    12.267143
# ...        ...           ...   ...          ...
# 22731      ZWE      Zimbabwe  2012    21.910075
# 22732      ZWE      Zimbabwe  2013    21.624350
# 22733      ZWE      Zimbabwe  2014    21.710483
# 22734      ZWE      Zimbabwe  2015    22.327625
# 22735      ZWE      Zimbabwe  2016    22.310167
#
# [22736 rows x 4 columns]

# %%
# Get Data Types
temperature_data_df.dtypes
# Out:
# iso_code        object
# country         object
# year             int64
# Temperature    float64
# dtype: object

# %%
# Create temperature_data table in Postgres DB from dataframe
temperature_data_df.to_sql(name="temperature_data", con=engine, if_exists='replace', index=False)

# %% [markdown]
# ## Load Country Government Data to Postgres Database

# %%
# Load Government data to dataframe
government_data_file = 'Resources/Country_Governments.csv'
government_data_df = pd.read_csv(government_data_file)
government_data_df
# Out:
#          country constitutional_form head_of_state  \
# 0    Afghanistan            Republic     Executive
# 1        Albania            Republic    Ceremonial
# 2        Algeria            Republic     Executive
# 3         Angola            Republic     Executive
# 4      Argentina            Republic     Executive
# ..           ...                 ...           ...
# 149    Venezuela            Republic     Executive
# 150      Vietnam            Republic     Executive
# 151        Yemen         Provisional           NaN
# 152       Zambia            Republic     Executive
# 153     Zimbabwe            Republic     Executive
#
#                          basis_of_executive_legitimacy
# 0             Presidency is independent of legislature
# 1      Ministry is subject to parliamentary confidence
# 2    Presidency independent of legislature; ministr...
# 3             Presidency is independent of legislature
# 4             Presidency is independent of legislature
# ...

# %%
# Get Data Types
government_data_df.dtypes
# Out:
# country                          object
# constitutional_form              object
# head_of_state                    object
# basis_of_executive_legitimacy    object
# dtype: object

# %%
# Create government data table in Postgres DB from dataframe
government_data_df.to_sql(name="government_data", con=engine, if_exists='replace', index=False)

# %% [markdown]
# ## Load Emissions Government Data to Postgres Database

# %%
# Load Emissions Government data to dataframe
emissions_gov_data_file = 'Resources/Emissions_gov_data.csv'
emissions_gov_data_df = pd.read_csv(emissions_gov_data_file)
emissions_gov_data_df
# Out:
#            Country  Year     CO2  Temperature  Population           GDP  \
# 0      Afghanistan  1950   0.084    11.619864   7752000.0  1.949480e+10
# 1      Afghanistan  1951   0.092    12.647118   7840000.0  2.006385e+10
# 2      Afghanistan  1952   0.092    12.805239   7936000.0  2.074235e+10
# 3      Afghanistan  1953   0.106    13.272074   8040000.0  2.201546e+10
# 4      Afghanistan  1954   0.106    12.419927   8151000.0  2.248333e+10
# ...            ...   ...     ...          ...         ...           ...
# 10210     Zimbabwe  2011   9.498    21.714008  12894000.0  1.830726e+10
# 10211     Zimbabwe  2012   7.695    21.910075  13115000.0  2.048226e+10
# 10212     Zimbabwe  2013  11.632    21.624350  13350000.0  2.374258e+10
# 10213     Zimbabwe  2014  11.962    21.710483  13587000.0  2.474828e+10
# 10214     Zimbabwe  2015  12.163    22.327625  13815000.0  2.503057e+10
#
#        Political_Regime_Rating  GDP_per_Capita  CO2_per_Capita  \
# ...

# %%
# Get Data Types
emissions_gov_data_df.dtypes
# Out:
# Country                     object
# Year                         int64
# CO2                        float64
# Temperature                float64
# Population                 float64
# GDP                        float64
# Political_Regime_Rating    float64
# GDP_per_Capita             float64
# CO2_per_Capita             float64
# CO2_per_Unit_GDP           float64
# Emission_Ratio              object
# dtype: object

# %%
# Create government data table in Postgres DB from dataframe
emissions_gov_data_df.to_sql(name="emissions_gov_data", con=engine, if_exists='replace', index=False)

# %% [markdown]
# ## Load Paris Climate Agreement Data to Postgres Database

# %%
# Load Paris Climate Agreement data to dataframe
paris_agreement_data_file = 'Resources/paris-agreement-entry-into-force.csv'
paris_agreement_data_df = pd.read_csv(paris_agreement_data_file)
paris_agreement_data_df
# Out:
#     Code         Name Signature Ratification          Kind DateOfEffect  \
# 0    AFG  Afghanistan   4/22/16      2/15/17  Ratification      3/17/17
# 1    ALB      Albania   4/22/16      9/21/16  Ratification      11/4/16
# 2    DZA      Algeria   4/22/16     10/20/16  Ratification     11/19/16
# 3    AND      Andorra   4/22/16      3/24/17  Ratification      4/23/17
# 4    AGO       Angola   4/22/16     11/16/20  Ratification     12/16/20
# ..   ...          ...       ...          ...           ...          ...
# 192  VEN    Venezuela   4/22/16      7/21/17  Ratification      8/20/17
# 193  VNM     Viet Nam   4/22/16      11/3/16      Approval      12/3/16
# 194  YEM        Yemen   9/23/16          NaN           NaN          NaN
# 195  ZMB       Zambia   9/20/16      12/9/16  Ratification       1/8/17
# 196  ZWE     Zimbabwe   4/22/16       8/7/17  Ratification       9/6/17
#
#      Emissions  Percentage    Year ParisAgreement
# 0      19328.0        0.05  2005.0            Yes
# ...

# %%
# Get Data Types
paris_agreement_data_df.dtypes
# Out:
# Code               object
# Name               object
# Signature          object
# Ratification       object
# Kind               object
# DateOfEffect       object
# Emissions         float64
# Percentage        float64
# Year              float64
# ParisAgreement     object
# dtype: object

# %%
# Create Paris Climate Agreement data table in Postgres DB from dataframe
paris_agreement_data_df.to_sql(name="paris_agreement_data", con=engine, if_exists='replace', index=False)
